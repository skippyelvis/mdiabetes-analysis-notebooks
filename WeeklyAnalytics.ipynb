# %%
from utils.message_analytics import bar_hist, bar_sum_hist, heatmap_running_hist
from utils.ai_analytics import plot_loss, plot_cluster_counts

# %%
w = 10

# %%
# this weeks messages
bar_hist(w)
bar_sum_hist()
heatmap_running_hist(cmap="plasma")

# %%
# weekly ai metrics
plot_cluster_counts(w)
plot_loss(w)
